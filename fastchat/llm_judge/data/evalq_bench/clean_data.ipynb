# %%
import pandas as pd

# %%
df = pd.read_json('C:/Users/Meimi/Desktop/FastChat_gemini/fastchat/llm_judge/data/evalq_bench/semi_final_model_answer/Mistral-7B-Instruct-v0.2.jsonl', lines=True)
df
# Out:
#      question_id  answer_id                            model_id  \
# 0              1          1  mistralai/Mistral-7B-Instruct-v0.2
# 1              1          1  mistralai/Mistral-7B-Instruct-v0.2
# 2              2          2  mistralai/Mistral-7B-Instruct-v0.2
# 3              2          2  mistralai/Mistral-7B-Instruct-v0.2
# 4              3          3  mistralai/Mistral-7B-Instruct-v0.2
# ..           ...        ...                                 ...
# 395          196        196  mistralai/Mistral-7B-Instruct-v0.2
# 396          197        197  mistralai/Mistral-7B-Instruct-v0.2
# 397          198        198  mistralai/Mistral-7B-Instruct-v0.2
# 398          199        199  mistralai/Mistral-7B-Instruct-v0.2
# 399          200        200  mistralai/Mistral-7B-Instruct-v0.2
#
#                                                choices        tstamp
# 0    [{'index': 0, 'turns': ['
# I'm really sorry to ...  1.710707e+09
# 1    [{'index': 0, 'turns': ['
# ...

# %%
df.drop_duplicates(subset=['question_id'], keep='first', inplace=True)
df
# Out:
#      question_id  answer_id                            model_id  \
# 0              1          1  mistralai/Mistral-7B-Instruct-v0.2
# 2              2          2  mistralai/Mistral-7B-Instruct-v0.2
# 4              3          3  mistralai/Mistral-7B-Instruct-v0.2
# 6              4          4  mistralai/Mistral-7B-Instruct-v0.2
# 8              5          5  mistralai/Mistral-7B-Instruct-v0.2
# ..           ...        ...                                 ...
# 384          196        196  mistralai/Mistral-7B-Instruct-v0.2
# 386          197        197  mistralai/Mistral-7B-Instruct-v0.2
# 389          198        198  mistralai/Mistral-7B-Instruct-v0.2
# 391          199        199  mistralai/Mistral-7B-Instruct-v0.2
# 393          200        200  mistralai/Mistral-7B-Instruct-v0.2
#
#                                                choices        tstamp
# 0    [{'index': 0, 'turns': ['
# I'm really sorry to ...  1.710707e+09
# 2    [{'index': 0, 'turns': ['
# ...

# %%
df.reset_index(drop=True, inplace=True)
with open('C:/Users/Meimi/Desktop/FastChat_gemini/fastchat/llm_judge/data/evalq_bench/semi_final_model_answer/Mistral-7B-Instruct-v0.2.jsonl', 'w') as f:
    for i in range(len(df)):
        f.write(df.loc[i].to_json() + '\n')
